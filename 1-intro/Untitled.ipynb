# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

X = np.linspace(-10, 10, 100)
y = np.sin(x)
plt.plot(x, y, marker="x")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/matplotlib/font_manager.py in <module>()
#    1428         try:
# -> 1429             fontManager = pickle_load(_fmcache)
#    1430             if (not hasattr(fontManager, '_version') or
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/matplotlib/font_manager.py in pickle_load(filename)
#     964     """
# --> 965     with open(filename, 'rb') as fh:
#     966         data = pickle.load(fh)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/kentana20/.matplotlib/fontList.py3k.cache'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5e546003a4dc> in <module>()
#       1 import numpy as np
#       2
# ----> 3 get_ipython().magic('matplotlib inline')
#       4 import matplotlib.pyplot as plt
#       5
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-104> in matplotlib(self, line)
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      98             print("Available matplotlib backends: %s" % backends_list)
#      99         else:
# --> 100             gui, backend = self.shell.enable_matplotlib(args.gui)
#     101             self._show_matplotlib_backend(args.gui, backend)
#     102
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    2945                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    2946
# -> 2947         pt.activate_matplotlib(backend)
#    2948         pt.configure_inline_support(self, backend)
#    2949
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/IPython/core/pylabtools.py in activate_matplotlib(backend)
#     292     matplotlib.rcParams['backend'] = backend
#     293
# --> 294     import matplotlib.pyplot
#     295     matplotlib.pyplot.switch_backend(backend)
#     296
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/matplotlib/pyplot.py in <module>()
#      27 from cycler import cycler
#      28 import matplotlib
# ---> 29 import matplotlib.colorbar
#      30 from matplotlib import style
#      31 from matplotlib import _pylab_helpers, interactive
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/matplotlib/colorbar.py in <module>()
#      34 import matplotlib.collections as collections
#      35 import matplotlib.colors as colors
# ---> 36 import matplotlib.contour as contour
#      37 import matplotlib.cm as cm
#      38 import matplotlib.gridspec as gridspec
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/matplotlib/contour.py in <module>()
#      20 import matplotlib.colors as colors
#      21 import matplotlib.collections as mcoll
# ---> 22 import matplotlib.font_manager as font_manager
#      23 import matplotlib.text as text
#      24 import matplotlib.cbook as cbook
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/matplotlib/font_manager.py in <module>()
#    1437             raise
#    1438         except:
# -> 1439             _rebuild()
#    1440     else:
#    1441         _rebuild()
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/matplotlib/font_manager.py in _rebuild()
#    1416         global fontManager
#    1417
# -> 1418         fontManager = FontManager()
#    1419
#    1420         if _fmcache:
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/matplotlib/font_manager.py in __init__(self, size, weight)
#    1051         #  Load TrueType fonts and create font dictionary.
#    1052
# -> 1053         self.ttffiles = findSystemFonts(paths) + findSystemFonts()
#    1054         self.defaultFamily = {
#    1055             'ttf': 'DejaVu Sans',
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/matplotlib/font_manager.py in findSystemFonts(fontpaths, fontext)
#     334                     fontfiles.add(f)
#     335
# --> 336             for f in get_fontconfig_fonts(fontext):
#     337                 fontfiles.add(f)
#     338
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/matplotlib/font_manager.py in get_fontconfig_fonts(fontext)
#     301     """
#     302     fontext = get_fontext_synonyms(fontext)
# --> 303     return [fname for fname in _call_fc_list()
#     304             if os.path.splitext(fname)[1][1:] in fontext]
#     305
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/matplotlib/font_manager.py in _call_fc_list()
#     282     timer.start()
#     283     try:
# --> 284         out = subprocess.check_output([str('fc-list'), '--format=%{file}'])
#     285     except (OSError, subprocess.CalledProcessError):
#     286         return []
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     334
#     335     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 336                **kwargs).stdout
#     337
#     338
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     403     with Popen(*popenargs, **kwargs) as process:
#     404         try:
# --> 405             stdout, stderr = process.communicate(input, timeout=timeout)
#     406         except TimeoutExpired:
#     407             process.kill()
#
# /Users/kentana20/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/subprocess.py in communicate(self, input, timeout)
#     821                 self._stdin_write(input)
#     822             elif self.stdout:
# --> 823                 stdout = self.stdout.read()
#     824                 self.stdout.close()
#     825             elif self.stderr:
#
# KeyboardInterrupt:

# %%
import matplotlib as mpl
print(mpl.rcParams['font.family'])
